# %%
import pandas as pd

# %%
data = pd.read_csv("country_vaccination_stats.csv")

# %%
data
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020                 NaN
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             1502 non-null   object
#  1   date                1502 non-null   object
#  2   daily_vaccinations  1442 non-null   float64
#  3   vaccines            1502 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 47.1+ KB

# %%
data.groupby("country").agg([min,max])
# Out:
#                             date             daily_vaccinations             \
#                              min         max                min        max
# country
# Argentina               1/1/2021  12/31/2020             6483.0    15656.0
# Austria                1/10/2021    1/9/2021             3368.0    12552.0
# Bahrain                 1/1/2021  12/31/2020              943.0    11106.0
# Belgium                 1/1/2021  12/31/2020                1.0    13135.0
# Brazil                 1/16/2021   1/25/2021              112.0    99928.0
# Bulgaria                1/1/2021  12/31/2020              472.0     2889.0
# Canada                  1/1/2021  12/31/2020              866.0    39910.0
# Chile                   1/1/2021  12/31/2020               51.0     6328.0
# China                   1/1/2021  12/31/2020           187500.0   714286.0
# Costa Rica              1/1/2021  12/31/2020              240.0     2158.0
# ...

# %%
data.isna().sum()
# Out:
# country               0
# date                  0
# daily_vaccinations    0
# vaccines              0
# dtype: int64

# %%
data.iloc[:,0]
# Out:
# 0       Argentina
# 1       Argentina
# 2       Argentina
# 3       Argentina
# 4       Argentina
#           ...
# 1497        Wales
# 1498        Wales
# 1499        Wales
# 1500        Wales
# 1501        Wales
# Name: country, Length: 1502, dtype: object

# %%
for column in data.iloc[:,0]:
  selected_country = data[data["country"] == column]
  daily = selected_country["daily_vaccinations"].min()
  data["daily_vaccinations"].fillna(value=daily,inplace = True)

# %%
data.isna().sum()
# Out:
# country               0
# date                  0
# daily_vaccinations    0
# vaccines              0
# dtype: int64

# %%
data[data["country"] == "Brazil"]
# Out:
#     country       date  daily_vaccinations vaccines
# 103  Brazil  1/16/2021              6483.0  Sinovac
# 104  Brazil  1/17/2021               112.0  Sinovac
# 105  Brazil  1/18/2021               554.0  Sinovac
# 106  Brazil  1/19/2021              3823.0  Sinovac
# 107  Brazil  1/20/2021              7136.0  Sinovac
# 108  Brazil  1/21/2021             27304.0  Sinovac
# 109  Brazil  1/22/2021             40980.0  Sinovac
# 110  Brazil  1/23/2021             76825.0  Sinovac
# 111  Brazil  1/24/2021             86373.0  Sinovac
# 112  Brazil  1/25/2021             99928.0  Sinovac
